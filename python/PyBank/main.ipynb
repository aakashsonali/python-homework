# %%
# Import the pathlib and csv library
from pathlib import Path
import csv

# Set the file path
file = Path('test.csv')



with open(file , "r") as file:
    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(file, delimiter=',')
    csv_header= next(csvreader)
     

  
 
    # Go to the next row from the start of the file
    # (which is often the first row/header) and iterate line_num by 1

   # line_num += 1
    # Print the header
    print(f"{csv_header} <---- HEADER")
      
    # metric values
    count=0
    total=0
    average=0
    changes=[]
    months=[]
    increase=0
    decrease=0
    
    
    
    # Read each row of data after the header
    for row in csvreader:
        # Print the row
        
        count += 1
        
        total += int(row[1])
        
        if row[0]!= "Jan-2010":
            change= int(row[1])- prev_row
            changes.append(change)
            months.append(row[0])
            
        prev_row=int(row[1])
        
        
        
#add all the changes up then divide by number of changes
average= sum (changes)/ len(changes)

decrease= min(changes)

increase= max(changes) 

decrease_index= changes.index(decrease)
increase_index= changes.index(increase)
print (changes)
print(decrease_index)
""" The total number of months included in the dataset


The net total amount of Profit/Losses over the entire period.


The average of the changes in Profit/Losses over the entire period.


The greatest increase in profits (date and amount) over the entire period.


The greatest decrease in profits (date and amount) over the entire period  """
report=f"""
 Financial Analysis
----------------------------
Total Months: 86 {count}
Total: $38382578 ${total}
Average  Change: $-2315.12 {average}
Greatest Increase in Profits: Feb-2012($1926159){months[increase_index]} {increase}
Greatest Decrease in Profits: Sep-2013{months[decrease_index]} ($-2196167){decrease}"""
print (report)
# Out:
# ['Date', 'Profit/Losses'] <---- HEADER
# [116771, -662642, -391430, 379920, 212354, 510239, -428211, -821271, 693918, 416278, -974163, 860159, -1115009, 1033048, 95318, -308093, 99052, -521393, 605450, 231727, -65187, -702716, 177975, -1065544, 1926159, -917805, 898730, -334262, -246499, -64055, -1529236, 1497596, 304914, -635801, 398319, -183161, -37864, -253689, 403655, 94168, 306877, -83000, 210462, -2196167, 1465222, -956983, 1838447, -468003, -64602, 206242, -242155, -449079, 315198, 241099, 111540, 365942, -219310, -368665, 409837, 151210, -110244, -341938, -1212159, 683246, -70825, 335594, 417334, -272194, -236462, 657432, -211262, -128237, -1750387, 925441, 932089, -311434, 267252, -1876758, 1733696, 198551, -665765, 693229, -734926, 77242, 532869]
# 43
#
#  Financial Analysis
# ----------------------------
# Total Months: 86 86
# Total: $38382578 $38382578
# Average  Change: $-2315.12 -2315.1176470588234
# Greatest Increase in Profits: Feb-2012($1926159)Feb-2012 1926159
# ...
